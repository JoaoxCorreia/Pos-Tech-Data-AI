# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoxCorreia/Pos-Tech-Data-AI/blob/main/Manipulacao_strings_completa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 1

# %% [markdown]
# Começando a Aula de Python

# %%
5
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %% [markdown]
# Textos ou palavras são chamados de string

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %%
print('Olá mundo')
# Out:
# Olá mundo

# %%
print("Olá mundo " + "5")
# Out:
# Olá mundo 5

# %%
5 + 2
# Out:
# 7

# %%
print(5 + 2)
# Out:
# 7

# %%
produto1 = 5

# %%
print(produto1)
# Out:
# 5

# %%
produto2 = 2000

# %%
print(produto2)
# Out:
# 2000

# %%
produto3 = 1

# %%
print(produto1 + produto2 + produto3)
# Out:
# 2006

# %%
nome_do_produto1 = "Macarrão"
nome_do_produto2 = "Celular"
nome_do_produto3 = "Bala"

# %%
print(nome_do_produto1 + " " + nome_do_produto2 + " " + nome_do_produto3)
# Out:
# Macarrão Celular Bala

# %%
amigos = 5
aluguel = 1000
supermercado = 500
carro = 400

# %%
total = aluguel + supermercado + carro

# %%
print(total)
# Out:
# 1900

# %%
aluguel = 900
total = aluguel + supermercado + carro

# %%
print(total)
# Out:
# 1800

# %%
aluguel = aluguel - 100

# %%
print(aluguel)
# Out:
# 800

# %%
amigos = 6
aluguel = 1000
supermercado = 500
carro = 400

# %%
print(amigos)
# Out:
# 6

# %%
print(carro * 2)
# Out:
# 800

# %%
total_de_carros = carro * 2

# %%
print(total_de_carros)
# Out:
# 800

# %%
total = aluguel + supermercado + total_de_carros
print(total)
# Out:
# 2300

# %%
total_por_pessoa = total / amigos
print(total_por_pessoa)
# Out:
# 383.3333333333333

# %%
type(aluguel)
# Out:
# int

# %%
type(total_por_pessoa)
# Out:
# float

# %%
type(nome_do_produto1)
# Out:
# str

# %%
pedro_tem_carteira_de_motorista = True
mario_tem_carteira_de_motorista = False

# %%
type(mario_tem_carteira_de_motorista)
# Out:
# bool

# %% [markdown]
# Inicial: "   Fabrício CARRaro   da alura   "<br>
# Final: "FABRÍCIO CARRARO DA ALURA"

# %%
texto = "   Fabrício CARRaro  da alura   "

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
print(texto.lower())
# Out:
#    fabrício carraro  da alura

# %%
print(texto.upper())
# Out:
#    FABRÍCIO CARRARO  DA ALURA

# %%
print(texto.strip())
# Out:
# Fabrício CARRaro  da alura

# %%
print(texto.replace("  ", " "))
# Out:
#   Fabrício CARRaro da alura

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
print(texto.strip().upper().replace("  ", " "))
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
print(texto)
# Out:
#    Fabrício CARRaro  da alura

# %%
texto = texto.strip().upper().replace("  ", " ")
print(texto)
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
print(texto)
# Out:
# FABRÍCIO CARRARO DA ALURA

# %%
nome = input("Digite o seu nome: ")
# Out:
# Digite o seu nome: Fabrício

# %%
print(nome)
# Out:
# Fabrício

# %%
idade = input("Digite a sua idade: ")
# Out:
# Digite a sua idade: 18

# %%
print(idade)
# Out:
# 18

# %%
type(nome)
# Out:
# str

# %%
type(idade)
# Out:
# str

# %%
idade = int(idade)

# %%
type(idade)
# Out:
# int

# %%
print("A pessoa se chama " + nome + " e tem " + str(idade) + " anos de idade.")
# Out:
# A pessoa se chama Fabrício e tem 18 anos de idade.

# %%
print(f"A pessoa se chama {nome} e tem {idade} anos de idade.")
# Out:
# A pessoa se chama Fabrício e tem 18 anos de idade.

# %% [markdown]
# ### Estruturas Condicionais

# %%
nome = input("Digite o seu nome: ")
# Out:
# Digite o seu nome: Fabrício

# %%
idade = int(input("Digite a sua idade: "))
# Out:
# Digite a sua idade: 18

# %%
type(idade)
# Out:
# int

# %%
if idade >= 18:
    print(f"O {nome} pode entrar na festa porque ele é maior de idade.")
    print(f"Ele tem {idade} anos de idade.")
else:
    print(f"O {nome} NÃO pode entrar na festa porque ele é menor de idade.")
    print(f"Ele tem {idade} anos de idade.")
# Out:
# O Fabrício pode entrar na festa porque ele é maior de idade.
# Ele tem 18 anos de idade.

# %%
media = float(input("Digite a sua média: "))

if media >= 7.0:
    print("Aprovado!")
elif media >= 5.0:
    print("Recuperação!")
else:
    print("Reprovado!")
# Out:
# Digite a sua média: 7.6
# Aprovado!

# %%
media = float(input("Digite a sua média: "))

if media < 5.0:
    print("Reprovado!")
elif media >= 5.0 and media < 7.0:
    print("Recuperação!")
else:
    print("Aprovado!")
# Out:
# Digite a sua média: 5.6
# Recuperação!

# %% [markdown]
# Rodando **IA**

# %%
import os
from google.colab import userdata
os.environ ["GOOGLE_API_KEY"] = userdata.get('Alura')

# %%
import google.generativeai as genai

model = genai.GenerativeModel('gemini-flash-latest')

# %%
response = model.generate_content("o que é a inteligência artificial")
print(response.text)
# Out:
# Esta é uma excelente pergunta que toca em uma das tecnologias mais transformadoras do nosso tempo.
#
# Aqui está uma explicação detalhada sobre o que é a Inteligência Artificial (IA).
#
# ---
#
# ## O que é a Inteligência Artificial (IA)?
#
# Em sua essência, a **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas e máquinas que possam realizar tarefas que, tipicamente, exigiriam inteligência humana.
#
# O objetivo da IA é permitir que as máquinas **pensem, aprendam, tomem decisões e resolvam problemas** de forma autônoma ou semi-autônoma.
#
# ### 1. A Definição Simples
#
# Podemos dizer que a IA é a capacidade de um software ou sistema imitar o comportamento inteligente humano.
#
# *   **Se um humano consegue fazer:** Aprender com experiências passadas, reconhecer padrões, planejar o futuro, entender a linguagem.
# *   **A IA consegue fazer:** Processar grandes volumes de dados (Big Data), identificar padrões complexos, prever resultados e tomar ações baseadas nesses dados.
#
# ### 2. Os Pilares da IA: Como Ela Funciona
#
# A IA não é apenas um único programa; é um conjunto de metodologias e tecnologias. As duas mais importantes são:
#
# #### a) Aprendizado de Máquina (Machine Learning - ML)
#
# Este é o subcampo mais popular da IA atualmente. O ML não é programado para seguir uma regra fixa; ele é programado para **aprender com os dados**.
#
# *   **Processo:** Você fornece a um algoritmo uma grande quantidade de dados (imagens, textos, números). O algoritmo, através de estatísticas complexas, identifica padrões nesses dados e usa esses padrões para fazer previsões ou tomar decisões.
# *   **Exemplo:** Se você alimenta um sistema de ML com milhares de fotos rotuladas como "gato" e "cachorro", ele aprenderá a diferenciar os dois, mesmo que nunca tenha visto uma foto específica antes.
#
# #### b) Aprendizado Profundo (Deep Learning - DL)
#
# O Deep Learning é um subconjunto do Machine Learning que utiliza **Redes Neurais Artificiais** com múltiplas camadas (por isso, "profundo"). Essas redes imitam a estrutura e a função do cérebro humano.
#
# *   **Utilização:** O DL é extremamente poderoso para tarefas complexas como reconhecimento facial, tradução automática e carros autônomos.
#
# ### 3. Classificações da IA (Os Três Tipos)
#
# Embora o termo "IA" seja amplo, a maioria dos especialistas o divide em três categorias, dependendo da sua capacidade:
#
# | Tipo de IA | Nível de Inteligência | O que Faz | Onde Encontramos Hoje |
# | :--- | :--- | :--- | :--- |
# | **1. IA Fraca (Narrow AI)** | Limitada/Específica | É especializada em **apenas uma tarefa** (e faz isso muito bem). | Assistentes virtuais (Siri, Alexa), algoritmos de recomendação (Netflix, Spotify), filtros de spam. **É a IA que usamos hoje.** |
# | **2. IA Geral (General AI)** | Semelhante à Humana | É capaz de realizar **qualquer tarefa intelectual** que um ser humano possa fazer, aplicando conhecimento em diferentes domínios. | **Ainda é teórica.** Não existe atualmente um sistema de IA Geral funcional. |
# | **3. Super IA (Superintelligence)** | Superior à Humana | Seria uma IA que excede a capacidade cognitiva humana em praticamente todos os aspectos (ciência, criatividade, solução de problemas). | **Estritamente hipotética.** |
#
# ### 4. Exemplos Práticos no Dia a Dia
#
# A IA está presente em quase todos os lugares que usamos tecnologia:
#
# 1.  **Assistentes Virtuais:** Siri, Google Assistant e Alexa usam Processamento de Linguagem Natural (PLN) para entender comandos de voz e responder.
# 2.  **Recomendações:** A Netflix usa IA para analisar o que você assistiu e sugerir o próximo conteúdo. O Facebook e o Instagram usam IA para decidir qual postagem mostrar no seu feed.
# 3.  **Saúde:** IA é usada para analisar imagens médicas (raio-x, ressonâncias) e ajudar a detectar doenças (como câncer) mais rapidamente do que os olhos humanos.
# 4.  **Finanças:** Bancos usam IA para detectar fraudes em tempo real e gerenciar riscos de investimento.
# 5.  **Tradução:** Ferramentas como o Google Translate usam Deep Learning para traduzir textos entre idiomas com alta precisão.
#
# ### Em Resumo
#
# A **Inteligência Artificial** não é uma tecnologia futurista de ficção científica; é um conjunto complexo de algoritmos e softwares que usa dados para imitar o aprendizado e a tomada de decisão humanos. O seu principal impacto é a capacidade de **automatizar tarefas, otimizar processos e gerar insights** que seriam impossíveis de obter através de métodos tradicionais.
